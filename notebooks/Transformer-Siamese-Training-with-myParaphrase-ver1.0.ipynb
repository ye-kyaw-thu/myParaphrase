# %% [markdown]
# # Transformer-Siamese Training with myParaphrase (version 1.0)
#
# Note: Multi-Head Attention = Transformer

# %%
# !pwd
# Out:
# /home/yekyaw.thu/exp/siamese/multihead-siamese-nets

# %% [markdown]
# ## Check the GPUs Status

# %%
# !nvidia-smi
# Out:
# Fri Dec  2 19:56:52 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:0A:00.0 Off |                  N/A |
# | 30%   45C    P0    58W / 300W |      0MiB / 11019MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %% [markdown]
# ## Training

# %%
# !time python run.py train multihead QQP --experiment_name exp-Transformer-MYPARA --gpu 1,2,3
# Out:
# WARNING:tensorflow:From /home/yekyaw.thu/.conda/envs/siamese/lib/python3.6/site-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /home/yekyaw.thu/.conda/envs/siamese/lib/python3.6/site-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /home/yekyaw.thu/.conda/envs/siamese/lib/python3.6/site-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/yekyaw.thu/.conda/envs/siamese/lib/python3.6/site-packages/tflearn/config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# ...

# %% [markdown]
# ## Run Tensorboard on GPU Server Side
#
# (siamese) yekyaw.thu@gpu:~/exp/siamese/multihead-siamese-nets$ tensorboard --logdir logs/QQP/exp-Transformer-MYPARA/
# TensorBoard 1.15.0 at http://gpu.cadt.edu.kh:6007/ (Press CTRL+C to quit)

# %% [markdown]
# ## Port Forwarding on Local Machine
#
# C:\Users\801680>ssh -p xxxx -L localhost:6007:localhost:6007 -i C:\Users\801680\.ssh\id_rsa-for-cadt-gpu-server yekyaw.thu@103.16.63.233

# %% [markdown]
# ## Accuracy and Loss Graphs for Transformer-Siamese Model with myParaphrase (version 1.0)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Accuracy Graph

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Loss Graph

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Log Information

# %%
# !ls -R ./logs/QQP/exp-Transformer-MYPARA
# Out:
# ./logs/QQP/exp-Transformer-MYPARA:
# dev  train
#
# ./logs/QQP/exp-Transformer-MYPARA/dev:
# events.out.tfevents.1669985865.gpu.cadt.edu.kh
#
# ./logs/QQP/exp-Transformer-MYPARA/train:
# events.out.tfevents.1669985865.gpu.cadt.edu.kh

# %% [markdown]
# ## Model Folder Information

# %%
# !ls -lh ./model_dir/exp-Transformer-MYPARA/
# Out:
# total 12M
# -rw-r--r-- 1 yekyaw.thu domain users  235 Dec  2 19:59 checkpoint
# -rw-r--r-- 1 yekyaw.thu domain users  188 Dec  2 19:59 evaluation.ini
# -rw-r--r-- 1 yekyaw.thu domain users 1.3M Dec  2 19:58 model-500.data-00000-of-00001
# -rw-r--r-- 1 yekyaw.thu domain users 2.9K Dec  2 19:58 model-500.index
# -rw-r--r-- 1 yekyaw.thu domain users 1.1M Dec  2 19:58 model-500.meta
# -rw-r--r-- 1 yekyaw.thu domain users 1.3M Dec  2 19:58 model-560.data-00000-of-00001
# -rw-r--r-- 1 yekyaw.thu domain users 2.9K Dec  2 19:58 model-560.index
# -rw-r--r-- 1 yekyaw.thu domain users 1.1M Dec  2 19:58 model-560.meta
# -rw-r--r-- 1 yekyaw.thu domain users 1.3M Dec  2 19:59 model-600.data-00000-of-00001
# -rw-r--r-- 1 yekyaw.thu domain users 2.9K Dec  2 19:59 model-600.index
# -rw-r--r-- 1 yekyaw.thu domain users 1.1M Dec  2 19:59 model-600.meta
# -rw-r--r-- 1 yekyaw.thu domain users 1.3M Dec  2 19:59 model-630.data-00000-of-00001
# ...

# %%
# !cat ./model_dir/exp-Transformer-MYPARA/checkpoint
# Out:
# model_checkpoint_path: "model-700"
# all_model_checkpoint_paths: "model-500"
# all_model_checkpoint_paths: "model-560"
# all_model_checkpoint_paths: "model-600"
# all_model_checkpoint_paths: "model-630"
# all_model_checkpoint_paths: "model-700"

# %%
# !cat ./model_dir/exp-Transformer-MYPARA/evaluation.ini
# Out:
# [EVALUATION]
# mean_dev_acc = 0.8172500014305115
# last_dev_acc = 0.8224999904632568
# test_acc = 0.8117499962449074
# epoch_time = 00:00:08.71
# num_trains = 36009
# num_devs = 405
# num_tests = 4045

# %% [markdown]
# ## FIN for Transformer-Siamese Model with myParaphrase dataset (version 1.0)
