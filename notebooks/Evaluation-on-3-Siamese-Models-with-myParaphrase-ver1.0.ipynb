# %% [markdown]
# ## Evaluation on Three Siamese Models

# %%
# !pwd
# Out:
# /home/yekyaw.thu/exp/siamese/multihead-siamese-nets

# %% [markdown]
# ## Configurations

# %%
# !cat config/main.ini
# Out:
# [TRAINING]
# num_epochs = 10
# batch_size = 512
# eval_every = 20
# learning_rate = 0.001
# checkpoints_to_keep = 5
# save_every = 100
# log_device_placement = False
#
# [DATA]
# logs_path = logs
# model_dir = model_dir
#
# [PARAMS]
# embedding_size = 64
# loss_function = MSE
# char_embeddings = False

# %%
# !cat config/model/rnn.ini
# Out:
# [PARAMS]
# hidden_size = 128
# cell_type = GRU
# bidirectional = True

# %%
# !cat config/model/cnn.ini
# Out:
# [PARAMS]
# num_filters = 50,50,50
# filter_sizes = 2,3,4
# dropout_rate = 0.0

# %%
# !cat config/model/multihead.ini
# Out:
# [PARAMS]
# num_blocks = 2
# num_heads = 8
# use_residual = False
# dropout_rate = 0.0

# %% [markdown]
# Here, multihead = Transformer model

# %% [markdown]
# ## Checkpoints

# %%
# !cat ./model_dir/exp-RNN-MYPARA/checkpoint
# Out:
# model_checkpoint_path: "model-700"
# all_model_checkpoint_paths: "model-500"
# all_model_checkpoint_paths: "model-560"
# all_model_checkpoint_paths: "model-600"
# all_model_checkpoint_paths: "model-630"
# all_model_checkpoint_paths: "model-700"

# %%
# !cat ./model_dir/exp-CNN-MYPARA/checkpoint
# Out:
# model_checkpoint_path: "model-700"
# all_model_checkpoint_paths: "model-500"
# all_model_checkpoint_paths: "model-560"
# all_model_checkpoint_paths: "model-600"
# all_model_checkpoint_paths: "model-630"
# all_model_checkpoint_paths: "model-700"

# %%
# !cat ./model_dir/exp-Transformer-MYPARA/checkpoint
# Out:
# model_checkpoint_path: "model-700"
# all_model_checkpoint_paths: "model-500"
# all_model_checkpoint_paths: "model-560"
# all_model_checkpoint_paths: "model-600"
# all_model_checkpoint_paths: "model-630"
# all_model_checkpoint_paths: "model-700"

# %% [markdown]
# ## Training/Validation/Testing Results

# %%
# !cat ./model_dir/exp-RNN-MYPARA/evaluation.ini
# Out:
# [EVALUATION]
# mean_dev_acc = 0.8445000007748604
# last_dev_acc = 0.8674999922513962
# test_acc = 0.8515000000596047
# epoch_time = 00:00:11.38
# num_trains = 36009
# num_devs = 405
# num_tests = 4045

# %%
# !cat ./model_dir/exp-CNN-MYPARA/evaluation.ini
# Out:
# [EVALUATION]
# mean_dev_acc = 0.8812499925494194
# last_dev_acc = 0.8924999833106995
# test_acc = 0.8817500010132789
# epoch_time = 00:00:02.53
# num_trains = 36009
# num_devs = 405
# num_tests = 4045

# %%
# !cat ./model_dir/exp-Transformer-MYPARA/evaluation.ini
# Out:
# [EVALUATION]
# mean_dev_acc = 0.8172500014305115
# last_dev_acc = 0.8224999904632568
# test_acc = 0.8117499962449074
# epoch_time = 00:00:08.71
# num_trains = 36009
# num_devs = 405
# num_tests = 4045

# %% [markdown]
# ## Visualization of RNN, CNN and Transformer Siamese Results

# %% [markdown]
# (siamese) yekyaw.thu@gpu:~/exp/siamese/multihead-siamese-nets$ tensorboard --logdir=RNN:logs/QQP/exp-RNN-MYPARA/,CNN:logs/QQP/exp-CNN-MYPARA,Transformer:logs/QQP/exp-Transformer-MYPARA
# TensorBoard 1.15.0 at http://gpu.cadt.edu.kh:6007/ (Press CTRL+C to quit)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Detail Information

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Loss is as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Bigger Graphs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
